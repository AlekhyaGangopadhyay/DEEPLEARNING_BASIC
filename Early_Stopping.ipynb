# %% [markdown]
# <a href="https://colab.research.google.com/github/AlekhyaGangopadhyay/DEEPLEARNING_BASIC/blob/main/Early_Stopping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from pylab import rcParams
import matplotlib.pyplot as plt
import warnings
from mlxtend.plotting import plot_decision_regions
from matplotlib.colors import ListedColormap
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_circles
import seaborn as sns

# %%
X,y=make_circles(n_samples=100,noise=0.1,random_state=1)

# %%
sns.scatterplot(x=X[:,0], y=X[:,1], hue=y)
# Out:
# <Axes: >

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=2)

# %%
model=Sequential()
model.add(Dense(256,input_dim=2,activation='relu'))
model.add(Dense(1,activation='sigmoid'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
history=model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=3500,verbose=0)

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
plot_decision_regions(X_test,y_test.ravel(),clf=model,legend=2)
plot.show()
# Out:
# 9600/9600 ━━━━━━━━━━━━━━━━━━━━ 8s 874us/step
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3965/996476174.py in <cell line: 0>()
#       1 plot_decision_regions(X_test,y_test.ravel(),clf=model,legend=2)
# ----> 2 plot.show()
#
# NameError: name 'plot' is not defined

# %% [markdown]
# #Early Stopping

# %%
model.add(Dense(256, input_dim=2, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
callback=EarlyStopping(
    monitor="val_loss",
    min_delta=0.00001,
    patience=20,
    verbose=1,
    mode="auto",
    baseline=None,
    restore_best_weights=False
)

# %%
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=3500, callbacks=callback)
# Out:
# Epoch 1/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step - accuracy: 0.6875 - loss: 0.6670 - val_accuracy: 0.6000 - val_loss: 0.6823
# Epoch 2/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8125 - loss: 0.6544 - val_accuracy: 0.5500 - val_loss: 0.6803
# Epoch 3/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.5500 - loss: 0.6436 - val_accuracy: 0.4500 - val_loss: 0.6782
# Epoch 4/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.5125 - loss: 0.6346 - val_accuracy: 0.4500 - val_loss: 0.6763
# Epoch 5/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.5125 - loss: 0.6235 - val_accuracy: 0.4500 - val_loss: 0.6737
# Epoch 6/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6250 - loss: 0.6137 - val_accuracy: 0.6500 - val_loss: 0.6718
# Epoch 7/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8125 - loss: 0.6038 - val_accuracy: 0.6000 - val_loss: 0.6694
# Epoch 8/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8375 - loss: 0.5948 - val_accuracy: 0.6000 - val_loss: 0.6679
# Epoch 9/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8375 - loss: 0.5856 - val_accuracy: 0.6000 - val_loss: 0.6684
# Epoch 10/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8375 - loss: 0.5766 - val_accuracy: 0.6000 - val_loss: 0.6689
# Epoch 11/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8375 - loss: 0.5680 - val_accuracy: 0.6000 - val_loss: 0.6680
# Epoch 12/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8375 - loss: 0.5590 - val_accuracy: 0.6500 - val_loss: 0.6644
# Epoch 13/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8500 - loss: 0.5508 - val_accuracy: 0.6500 - val_loss: 0.6601
# Epoch 14/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8750 - loss: 0.5428 - val_accuracy: 0.6500 - val_loss: 0.6587
# Epoch 15/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8750 - loss: 0.5351 - val_accuracy: 0.6500 - val_loss: 0.6609
# Epoch 16/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8750 - loss: 0.5268 - val_accuracy: 0.6500 - val_loss: 0.6633
# Epoch 17/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8750 - loss: 0.5192 - val_accuracy: 0.6500 - val_loss: 0.6655
# Epoch 18/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8875 - loss: 0.5118 - val_accuracy: 0.6500 - val_loss: 0.6671
# Epoch 19/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8875 - loss: 0.5056 - val_accuracy: 0.6500 - val_loss: 0.6679
# Epoch 20/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8875 - loss: 0.4972 - val_accuracy: 0.7000 - val_loss: 0.6629
# Epoch 21/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9125 - loss: 0.4902 - val_accuracy: 0.7000 - val_loss: 0.6597
# Epoch 22/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9250 - loss: 0.4833 - val_accuracy: 0.7000 - val_loss: 0.6569
# Epoch 23/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9375 - loss: 0.4764 - val_accuracy: 0.7000 - val_loss: 0.6545
# Epoch 24/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9375 - loss: 0.4698 - val_accuracy: 0.7000 - val_loss: 0.6560
# Epoch 25/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9375 - loss: 0.4631 - val_accuracy: 0.7000 - val_loss: 0.6590
# Epoch 26/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9375 - loss: 0.4570 - val_accuracy: 0.7000 - val_loss: 0.6638
# Epoch 27/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9375 - loss: 0.4501 - val_accuracy: 0.7000 - val_loss: 0.6634
# Epoch 28/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9375 - loss: 0.4436 - val_accuracy: 0.7000 - val_loss: 0.6647
# Epoch 29/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9500 - loss: 0.4368 - val_accuracy: 0.6500 - val_loss: 0.6629
# Epoch 30/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9500 - loss: 0.4302 - val_accuracy: 0.6500 - val_loss: 0.6615
# Epoch 31/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9500 - loss: 0.4238 - val_accuracy: 0.6500 - val_loss: 0.6581
# Epoch 32/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9375 - loss: 0.4186 - val_accuracy: 0.6500 - val_loss: 0.6579
# Epoch 33/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9250 - loss: 0.4116 - val_accuracy: 0.6500 - val_loss: 0.6623
# Epoch 34/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9250 - loss: 0.4045 - val_accuracy: 0.6500 - val_loss: 0.6639
# Epoch 35/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9250 - loss: 0.3982 - val_accuracy: 0.6500 - val_loss: 0.6621
# Epoch 36/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9250 - loss: 0.3902 - val_accuracy: 0.6500 - val_loss: 0.6544
# Epoch 37/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9250 - loss: 0.3840 - val_accuracy: 0.6500 - val_loss: 0.6519
# Epoch 38/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9250 - loss: 0.3772 - val_accuracy: 0.6500 - val_loss: 0.6528
# Epoch 39/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9250 - loss: 0.3712 - val_accuracy: 0.6500 - val_loss: 0.6578
# Epoch 40/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9250 - loss: 0.3635 - val_accuracy: 0.6500 - val_loss: 0.6586
# Epoch 41/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9250 - loss: 0.3564 - val_accuracy: 0.6500 - val_loss: 0.6606
# Epoch 42/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9250 - loss: 0.3501 - val_accuracy: 0.6500 - val_loss: 0.6638
# Epoch 43/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9250 - loss: 0.3438 - val_accuracy: 0.6500 - val_loss: 0.6638
# Epoch 44/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9250 - loss: 0.3379 - val_accuracy: 0.6500 - val_loss: 0.6624
# Epoch 45/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9250 - loss: 0.3305 - val_accuracy: 0.6500 - val_loss: 0.6483
# Epoch 46/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9250 - loss: 0.3246 - val_accuracy: 0.6500 - val_loss: 0.6416
# Epoch 47/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9250 - loss: 0.3180 - val_accuracy: 0.6500 - val_loss: 0.6421
# Epoch 48/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9250 - loss: 0.3121 - val_accuracy: 0.6500 - val_loss: 0.6472
# Epoch 49/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9250 - loss: 0.3071 - val_accuracy: 0.6500 - val_loss: 0.6508
# Epoch 50/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9250 - loss: 0.3014 - val_accuracy: 0.7000 - val_loss: 0.6527
# Epoch 51/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9250 - loss: 0.2948 - val_accuracy: 0.7000 - val_loss: 0.6557
# Epoch 52/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9375 - loss: 0.2906 - val_accuracy: 0.7000 - val_loss: 0.6569
# Epoch 53/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9375 - loss: 0.2847 - val_accuracy: 0.7000 - val_loss: 0.6542
# Epoch 54/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9375 - loss: 0.2792 - val_accuracy: 0.7000 - val_loss: 0.6498
# Epoch 55/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9250 - loss: 0.2735 - val_accuracy: 0.7000 - val_loss: 0.6504
# Epoch 56/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9500 - loss: 0.2695 - val_accuracy: 0.7000 - val_loss: 0.6522
# Epoch 57/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9375 - loss: 0.2638 - val_accuracy: 0.7000 - val_loss: 0.6562
# Epoch 58/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9250 - loss: 0.2594 - val_accuracy: 0.7000 - val_loss: 0.6575
# Epoch 59/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9250 - loss: 0.2550 - val_accuracy: 0.7000 - val_loss: 0.6552
# Epoch 60/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9375 - loss: 0.2510 - val_accuracy: 0.7000 - val_loss: 0.6526
# Epoch 61/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9375 - loss: 0.2464 - val_accuracy: 0.7000 - val_loss: 0.6587
# Epoch 62/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9250 - loss: 0.2430 - val_accuracy: 0.6500 - val_loss: 0.6623
# Epoch 63/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9250 - loss: 0.2393 - val_accuracy: 0.6500 - val_loss: 0.6643
# Epoch 64/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9375 - loss: 0.2355 - val_accuracy: 0.6500 - val_loss: 0.6665
# Epoch 65/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9375 - loss: 0.2320 - val_accuracy: 0.6500 - val_loss: 0.6687
# Epoch 66/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9375 - loss: 0.2272 - val_accuracy: 0.6500 - val_loss: 0.6709
# Epoch 66: early stopping

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
plot_decision_regions(X_test, y_test.ravel(), clf = model, legend=2)
plt.show()
# Out:
# 9600/9600 ━━━━━━━━━━━━━━━━━━━━ 8s 848us/step
